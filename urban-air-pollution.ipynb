# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from fastai.tabular import *
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import KFold, StratifiedKFold
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import datetime
from tqdm.notebook import tqdm as tqdm_notebook
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
from functools import partial
import re
import calendar
import matplotlib.pyplot as plt
def add_cyclic_datepart(df, field_name:str, prefix:str=None, drop:bool=True, time:bool=False, add_linear:bool=False):
    "Helper function that adds trigonometric date/time features to a date in the column `field_name` of `df`."
    make_date(df, field_name)
    field = df[field_name]
    prefix = ifnone(prefix, re.sub('[Dd]ate$', '', field_name))
    series = field.apply(partial(cyclic_dt_features, time=time, add_linear=add_linear))
    columns = [prefix + c for c in cyclic_dt_feat_names(time, add_linear)]
    df_feats = pd.DataFrame([item for item in series], columns=columns, index=series.index)
    for column in columns: df[column] = df_feats[column]
    if drop: df.drop(field_name, axis=1, inplace=True)
    return df
def make_date(df, date_field:str):
    "Make sure `df[date_field]` is of the right date type."
    field_dtype = df[date_field].dtype
    if isinstance(field_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        field_dtype = np.datetime64
    if not np.issubdtype(field_dtype, np.datetime64):
        df[date_field] = pd.to_datetime(df[date_field], infer_datetime_format=True)
def ifnone(a,b):
    "`a` if `a` is not None, otherwise `b`."
    return b if a is None else a
def cyclic_dt_features(d, time:bool=True, add_linear:bool=False):
    "Calculate the cos and sin of date/time cycles."
    tt,fs = d.timetuple(), [np.cos, np.sin]
    day_year,days_month = tt.tm_yday, calendar.monthrange(d.year, d.month)[1]
    days_year = 366 if calendar.isleap(d.year) else 365
    rs = d.weekday()/7, (d.day-1)/days_month, (d.month-1)/12, (day_year-1)/days_year
    feats = [f(r * 2 * np.pi) for r in rs for f in fs]
    """if time and isinstance(d, datetime) and type(d) != date:
        rs = tt.tm_hour/24, tt.tm_hour%12/12, tt.tm_min/60, tt.tm_sec/60
        feats += [f(r * 2 * np.pi) for r in rs for f in fs]"""
    """if add_linear:
        if type(d) == date: feats.append(d.year + rs[-1])
        else:
            secs_in_year = (datetime(d.year+1, 1, 1) - datetime(d.year, 1, 1)).total_seconds()
            feats.append(d.year + ((d - datetime(d.year, 1, 1)).total_seconds() / secs_in_year))"""
    return feats
def cyclic_dt_feat_names(time:bool=True, add_linear:bool=False):
    "Return feature names of date/time cycles as produced by `cyclic_dt_features`."
    fs = ['cos','sin']
    attr = [f'{r}_{f}' for r in 'weekday day_month month_year day_year'.split() for f in fs]
    if time: attr += [f'{r}_{f}' for r in 'hour clock min sec'.split() for f in fs]
    if add_linear: attr.append('year_lin')
    return attr

# %%
# this function will help to reduce momory 
# data will be smaller with the same value

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# %%
train = pd.read_csv('../input/urban-air-pollution/Train.csv')
test = pd.read_csv('../input/urban-air-pollution/Test.csv')

train['Date'] = pd.to_datetime(train['Date'], format='%Y-%m-%d')
test['Date'] = pd.to_datetime(test['Date'], format='%Y-%m-%d')

ID_COL, TARGET_COL = 'Place_ID X Date', 'target'

# %%
df = pd.concat([train, test]).reset_index(drop=True)
features = [c for c in df.columns if c not in ['Date', 'target_count', 'target_min', 'Place_ID X Date', 'target_variance', 'Place_ID', 'target_max', 'target']]
simple_feats = [c for c in features if ('angle' not in c) & ('height' not in c) & ('altittude' not in c)]
len(simple_feats)
# Out:
# 38

# %%
nan_cols = [c for c in df.columns if c not in ["target_max","target","target_min","target_variance", "target_count"]]
nan_cols = df[nan_cols].columns[df[nan_cols].isnull().any()].tolist()

for col in nan_cols:
    
    while df[col].isnull().sum()>0:
     
        df[col].fillna(df[["Place_ID", col]].groupby(["Place_ID"]).shift(periods=0).fillna(method='ffill', limit=1).fillna(method='bfill', limit=1)[col], inplace=True) 

df.isnull().sum()[df.isnull().sum()>0]
# Out:
# target             16136
# target_min         16136
# target_max         16136
# target_variance    16136
# target_count       16136
# dtype: int64

# %%
df['placeID_freq'] = df['Place_ID'].map(df['Place_ID'].value_counts())

for i in range(1, 20):
    df[f'prev_target_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(i).fillna(method='ffill').fillna(method='bfill').sort_index()
    df[f'next_target_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(-i).fillna(method='bfill').fillna(method='ffill').sort_index()
for i in tqdm_notebook(range(1, 25)):
    df[f'magic_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(i).expanding().mean().fillna(method='ffill').fillna(method='bfill').sort_index()
    df[f'magic2_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(-i).expanding().mean().fillna(method='bfill').fillna(method='ffill').sort_index()
    
for i in tqdm_notebook(range(1, 45)):
    c = 'Date' + str(i+1)
    df[c] = df['Date']  + datetime.timedelta(days=i)
    _ = add_cyclic_datepart(df, c, prefix = c)
    
for i in tqdm_notebook(range(1, 22)):
    tmp = df.sort_values(by='Date').groupby('Place_ID')[simple_feats].shift(i).fillna(method='ffill').fillna(method='bfill').sort_index()
    tmp_diff_prev = df[simple_feats] - tmp
    tmp.columns = [c + f'_prev_{i}' for c in tmp.columns]
    tmp_diff_prev.columns = [c + f'_prev_diff_{i}' for c in tmp_diff_prev.columns]
    df = pd.concat([df, tmp, tmp_diff_prev], axis=1)
    
    tmp = df.sort_values(by='Date').groupby('Place_ID')[simple_feats].shift(-i).fillna(method='bfill').fillna(method='ffill').sort_index()
    tmp_diff_next = df[simple_feats] - tmp
    tmp.columns = [c + f'_next_{i}' for c in tmp.columns]
    tmp_diff_next.columns = [c + f'_next_diff_{i}' for c in tmp_diff_next.columns]
    df = pd.concat([df, tmp, tmp_diff_next], axis=1)
    
for attr in ['day', 'month', 'week', 'dayofweek', 'weekofyear', 'days_in_month', 'is_month_start', 'is_month_end', 'dayofyear']:
    df[attr] = getattr(df['Date'].dt, attr)
df['is_weekend'] = (df['dayofweek'] >= 5)*1
df['fortnight'] = df['day']%15
df['which_fortnight'] = df['day']//15

add_cyclic_datepart(df, "Date", prefix = "Current_Date_")
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/44 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:29: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#             Place_ID X Date Place_ID  target  target_min  target_max  \
# 0      010Q650 X 2020-01-02  010Q650    38.0        23.0        53.0
# 1      010Q650 X 2020-01-03  010Q650    39.0        25.0        63.0
# 2      010Q650 X 2020-01-04  010Q650    24.0         8.0        56.0
# 3      010Q650 X 2020-01-05  010Q650    49.0        10.0        55.0
# 4      010Q650 X 2020-01-06  010Q650    21.0         9.0        52.0
# ...                     ...      ...     ...         ...         ...
# 46688  ZZDJZMS X 2020-03-31  ZZDJZMS     NaN         NaN         NaN
# 46689  ZZDJZMS X 2020-04-01  ZZDJZMS     NaN         NaN         NaN
# 46690  ZZDJZMS X 2020-04-02  ZZDJZMS     NaN         NaN         NaN
# 46691  ZZDJZMS X 2020-04-03  ZZDJZMS     NaN         NaN         NaN
# 46692  ZZDJZMS X 2020-04-04  ZZDJZMS     NaN         NaN         NaN
#
#        target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0               769.50          92.0                             11.000000
# 1              1319.85          91.0                             14.600000
# 2              1181.96          96.0                             16.400000
# 3              1113.67          96.0                              6.911948
# 4              1164.82          95.0                             13.900001
# ...                ...           ...                                   ...
# 46688              NaN           NaN                              9.400001
# 46689              NaN           NaN                             17.000000
# 46690              NaN           NaN                             19.170641
# 46691              NaN           NaN                              8.400001
# 46692              NaN           NaN                              6.500000
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 0                              60.200001                            0.00804
# 1                              48.799999                            0.00839
# 2                              33.400002                            0.00750
# 3                              21.300001                            0.00391
# 4                              44.700001                            0.00535
# ...                                  ...                                ...
# 46688                          86.200005                            0.00413
# 46689                          90.300003                            0.00548
# 46690                          86.200005                            0.00656
# 46691                          66.400002                            0.00457
# 46692                          81.599998                            0.00508
#
#        ...  fortnight  which_fortnight  Current_Date_weekday_cos  \
# 0      ...          2                0                 -0.900969
# 1      ...          3                0                 -0.900969
# 2      ...          4                0                 -0.222521
# 3      ...          5                0                  0.623490
# 4      ...          6                0                  1.000000
# ...    ...        ...              ...                       ...
# 46688  ...          1                2                  0.623490
# 46689  ...          1                0                 -0.222521
# 46690  ...          2                0                 -0.900969
# 46691  ...          3                0                 -0.900969
# 46692  ...          4                0                 -0.222521
#
#        Current_Date_weekday_sin  Current_Date_day_month_cos  \
# 0                      0.433884                    0.979530
# 1                     -0.433884                    0.918958
# 2                     -0.974928                    0.820763
# 3                     -0.781831                    0.688967
# 4                      0.000000                    0.528964
# ...                         ...                         ...
# 46688                  0.781831                    0.979530
# 46689                  0.974928                    1.000000
# 46690                  0.433884                    0.978148
# 46691                 -0.433884                    0.913545
# 46692                 -0.974928                    0.809017
#
#        Current_Date_day_month_sin  Current_Date_month_year_cos  \
# 0                        0.201299                 1.000000e+00
# 1                        0.394356                 1.000000e+00
# 2                        0.571268                 1.000000e+00
# 3                        0.724793                 1.000000e+00
# 4                        0.848644                 1.000000e+00
# ...                           ...                          ...
# 46688                   -0.201299                 5.000000e-01
# 46689                    0.000000                 6.123234e-17
# 46690                    0.207912                 6.123234e-17
# 46691                    0.406737                 6.123234e-17
# 46692                    0.587785                 6.123234e-17
#
#        Current_Date_month_year_sin  Current_Date_day_year_cos  \
# 0                         0.000000                   0.999853
# 1                         0.000000                   0.999411
# 2                         0.000000                   0.998674
# 3                         0.000000                   0.997643
# 4                         0.000000                   0.996318
# ...                            ...                        ...
# 46688                     0.866025                   0.025748
# 46689                     1.000000                   0.008583
# 46690                     1.000000                  -0.008583
# 46691                     1.000000                  -0.025748
# 46692                     1.000000                  -0.042905
#
#        Current_Date_day_year_sin
# 0                       0.017166
# 1                       0.034328
# 2                       0.051479
# 3                       0.068615
# 4                       0.085731
# ...                          ...
# 46688                   0.999668
# 46689                   0.999963
# 46690                   0.999963
# 46691                   0.999668
# 46692                   0.999079
#
# [46693 rows x 3732 columns]

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# target             16136
# target_min         16136
# target_max         16136
# target_variance    16136
# target_count       16136
# dtype: int64

# %%
nan_cols = ['Date', 'target_count', 'target_min', 'Place_ID X Date', 'target_variance', 'Place_ID',
                                               'target_max', 'target',  'month_year_cos','month_year_sin','day_year_cos','day_year_sin']

features = [c for c in df.columns if c not in nan_cols]
train = df[:train.shape[0]].reset_index(drop=True)
test = df[train.shape[0]:].reset_index(drop=True)
target = train[TARGET_COL]

len(features)
# Out:
# 3725

# %%
train = reduce_mem_usage(train)
print('************************* \n')
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 869.64 MB
# Memory usage after optimization is: 240.82 MB
# Decreased by 72.3%
# *************************
#
# Memory usage of dataframe is 459.22 MB
# Memory usage after optimization is: 127.57 MB
# Decreased by 72.2%

# %%
del df
import gc
gc.collect()
# Out:
# 23

# %%
param = {'num_leaves': 100,
         'min_data_in_leaf': 40, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.05,
         "boosting": "gbdt",
         "feature_fraction": 0.35,
         "metric": 'auc',
         "lambda_l1": 1,
         "lambda_l2": 1,
         "random_state": 6,
         "verbosity": -1,
         'metric' : 'rmse',
         'num_iterations': 2500}

# %%
target_cols = ['target']
oofs_df = pd.DataFrame()
preds_df = pd.DataFrame()
for t_col in target_cols:
    oofs_df[t_col] = np.zeros(len(train))
    preds_df[t_col] = np.zeros(len(test))

# %%
max_iter = 10
folds = StratifiedKFold(n_splits=max_iter, random_state=None)

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, pd.qcut(target, 10, labels=False, duplicates='drop'))):
    print("\nfold n°{}".format(fold_))
    X_trn, X_val, X_test = train.iloc[trn_idx][features], train.iloc[val_idx][features], test[features]
    for t_col in target_cols:
        target = train[t_col]
        print(f"\n\n**** {t_col} ****\n")
        y_trn, y_val = target.iloc[trn_idx], target.iloc[val_idx]
        trn_data = lgb.Dataset(X_trn, y_trn)
        val_data = lgb.Dataset(X_val, y_val)
        
        clf = lgb.train(param, trn_data, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 150)

        oofs_df[t_col][val_idx] = clf.predict(X_val, num_iteration=clf.best_iteration)
        current_test_pred = clf.predict(X_test, num_iteration=clf.best_iteration)
        current_test_pred[current_test_pred < 0] = 0
        preds_df[t_col] += current_test_pred / folds.n_splits
        break
    gc.collect()
    #break
# Out:
# fold n°0
#
#
# **** target ****
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.5875	valid_1's rmse: 25.7926
# [200]	training's rmse: 11.9182	valid_1's rmse: 24.8324
# [300]	training's rmse: 8.66667	valid_1's rmse: 24.506
# [400]	training's rmse: 6.5646	valid_1's rmse: 24.3287
# [500]	training's rmse: 5.10005	valid_1's rmse: 24.2806
# [600]	training's rmse: 4.00674	valid_1's rmse: 24.2657
# [700]	training's rmse: 3.17213	valid_1's rmse: 24.2399
# [800]	training's rmse: 2.5346	valid_1's rmse: 24.2399
# Early stopping, best iteration is:
# [672]	training's rmse: 3.38011	valid_1's rmse: 24.2342
# 314
# fold n°1
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 16.1486	valid_1's rmse: 36.9105
# [200]	training's rmse: 10.6568	valid_1's rmse: 36.6006
# [300]	training's rmse: 7.72978	valid_1's rmse: 36.4212
# [400]	training's rmse: 5.87591	valid_1's rmse: 36.398
# [500]	training's rmse: 4.57631	valid_1's rmse: 36.3942
# [600]	training's rmse: 3.6266	valid_1's rmse: 36.3796
# [700]	training's rmse: 2.92025	valid_1's rmse: 36.3578
# [800]	training's rmse: 2.38842	valid_1's rmse: 36.3553
# [900]	training's rmse: 1.98211	valid_1's rmse: 36.3463
# [1000]	training's rmse: 1.66389	valid_1's rmse: 36.3373
# [1100]	training's rmse: 1.41394	valid_1's rmse: 36.3354
# [1200]	training's rmse: 1.21756	valid_1's rmse: 36.3352
# [1300]	training's rmse: 1.05613	valid_1's rmse: 36.3323
# [1400]	training's rmse: 0.925304	valid_1's rmse: 36.333
# Early stopping, best iteration is:
# [1313]	training's rmse: 1.03715	valid_1's rmse: 36.3321
# 534
# fold n°2
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.0425	valid_1's rmse: 33.2344
# [200]	training's rmse: 11.5434	valid_1's rmse: 32.0583
# [300]	training's rmse: 8.3089	valid_1's rmse: 31.6913
# [400]	training's rmse: 6.27456	valid_1's rmse: 31.561
# [500]	training's rmse: 4.83944	valid_1's rmse: 31.5046
# [600]	training's rmse: 3.8049	valid_1's rmse: 31.4698
# [700]	training's rmse: 3.01701	valid_1's rmse: 31.453
# [800]	training's rmse: 2.41409	valid_1's rmse: 31.4434
# [900]	training's rmse: 1.94648	valid_1's rmse: 31.4391
# [1000]	training's rmse: 1.58301	valid_1's rmse: 31.4301
# [1100]	training's rmse: 1.29649	valid_1's rmse: 31.426
# [1200]	training's rmse: 1.07299	valid_1's rmse: 31.4235
# [1300]	training's rmse: 0.894043	valid_1's rmse: 31.4214
# [1400]	training's rmse: 0.751264	valid_1's rmse: 31.4217
# [1500]	training's rmse: 0.635286	valid_1's rmse: 31.4189
# [1600]	training's rmse: 0.543977	valid_1's rmse: 31.4197
# [1700]	training's rmse: 0.470802	valid_1's rmse: 31.4185
# [1800]	training's rmse: 0.410232	valid_1's rmse: 31.4171
# [1900]	training's rmse: 0.360238	valid_1's rmse: 31.417
# [2000]	training's rmse: 0.317704	valid_1's rmse: 31.4155
# [2100]	training's rmse: 0.282819	valid_1's rmse: 31.4149
# [2200]	training's rmse: 0.252717	valid_1's rmse: 31.4142
# [2300]	training's rmse: 0.2277	valid_1's rmse: 31.4138
# [2400]	training's rmse: 0.20601	valid_1's rmse: 31.4136
# [2500]	training's rmse: 0.186573	valid_1's rmse: 31.4136
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.186573	valid_1's rmse: 31.4136
# 40
# fold n°3
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.5142	valid_1's rmse: 24.7542
# [200]	training's rmse: 11.8288	valid_1's rmse: 23.5038
# [300]	training's rmse: 8.56397	valid_1's rmse: 23.2966
# [400]	training's rmse: 6.48591	valid_1's rmse: 23.3699
# Early stopping, best iteration is:
# [301]	training's rmse: 8.53948	valid_1's rmse: 23.2801
# 336
# fold n°4
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.559	valid_1's rmse: 27.3693
# [200]	training's rmse: 11.9557	valid_1's rmse: 25.909
# [300]	training's rmse: 8.72048	valid_1's rmse: 25.438
# [400]	training's rmse: 6.61309	valid_1's rmse: 25.2695
# [500]	training's rmse: 5.1503	valid_1's rmse: 25.1679
# [600]	training's rmse: 4.05825	valid_1's rmse: 25.1142
# [700]	training's rmse: 3.21592	valid_1's rmse: 25.0735
# [800]	training's rmse: 2.57844	valid_1's rmse: 25.0419
# [900]	training's rmse: 2.07935	valid_1's rmse: 25.0254
# [1000]	training's rmse: 1.69157	valid_1's rmse: 25.0117
# [1100]	training's rmse: 1.38143	valid_1's rmse: 24.9989
# [1200]	training's rmse: 1.13783	valid_1's rmse: 24.9893
# [1300]	training's rmse: 0.942091	valid_1's rmse: 24.9795
# [1400]	training's rmse: 0.784157	valid_1's rmse: 24.9672
# [1500]	training's rmse: 0.656703	valid_1's rmse: 24.9624
# [1600]	training's rmse: 0.554729	valid_1's rmse: 24.9589
# [1700]	training's rmse: 0.471647	valid_1's rmse: 24.9547
# [1800]	training's rmse: 0.403766	valid_1's rmse: 24.9525
# [1900]	training's rmse: 0.34795	valid_1's rmse: 24.9503
# [2000]	training's rmse: 0.302454	valid_1's rmse: 24.9481
# [2100]	training's rmse: 0.264311	valid_1's rmse: 24.9464
# [2200]	training's rmse: 0.232401	valid_1's rmse: 24.9456
# [2300]	training's rmse: 0.205992	valid_1's rmse: 24.9445
# [2400]	training's rmse: 0.183689	valid_1's rmse: 24.9441
# [2500]	training's rmse: 0.163942	valid_1's rmse: 24.9432
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.163942	valid_1's rmse: 24.9432
# 44
# fold n°5
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.4082	valid_1's rmse: 25.9192
# [200]	training's rmse: 11.8373	valid_1's rmse: 24.6536
# [300]	training's rmse: 8.62485	valid_1's rmse: 24.2379
# [400]	training's rmse: 6.53537	valid_1's rmse: 24.0659
# [500]	training's rmse: 5.06942	valid_1's rmse: 23.9859
# [600]	training's rmse: 3.9913	valid_1's rmse: 23.9254
# [700]	training's rmse: 3.1644	valid_1's rmse: 23.8906
# [800]	training's rmse: 2.53219	valid_1's rmse: 23.8725
# [900]	training's rmse: 2.0394	valid_1's rmse: 23.8543
# [1000]	training's rmse: 1.65939	valid_1's rmse: 23.8355
# [1100]	training's rmse: 1.35996	valid_1's rmse: 23.8298
# [1200]	training's rmse: 1.12199	valid_1's rmse: 23.8258
# [1300]	training's rmse: 0.929657	valid_1's rmse: 23.8192
# [1400]	training's rmse: 0.776658	valid_1's rmse: 23.8131
# [1500]	training's rmse: 0.653083	valid_1's rmse: 23.8097
# [1600]	training's rmse: 0.552281	valid_1's rmse: 23.8065
# [1700]	training's rmse: 0.471093	valid_1's rmse: 23.8045
# [1800]	training's rmse: 0.404364	valid_1's rmse: 23.8043
# [1900]	training's rmse: 0.347867	valid_1's rmse: 23.8031
# [2000]	training's rmse: 0.301888	valid_1's rmse: 23.803
# [2100]	training's rmse: 0.263071	valid_1's rmse: 23.8017
# [2200]	training's rmse: 0.230779	valid_1's rmse: 23.8008
# [2300]	training's rmse: 0.203508	valid_1's rmse: 23.8006
# [2400]	training's rmse: 0.180319	valid_1's rmse: 23.8
# [2500]	training's rmse: 0.160426	valid_1's rmse: 23.7997
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.160426	valid_1's rmse: 23.7997
# 42
# fold n°6
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.1587	valid_1's rmse: 32.6362
# [200]	training's rmse: 11.7237	valid_1's rmse: 31.9294
# [300]	training's rmse: 8.49762	valid_1's rmse: 31.5938
# [400]	training's rmse: 6.4492	valid_1's rmse: 31.407
# [500]	training's rmse: 5.00679	valid_1's rmse: 31.3262
# [600]	training's rmse: 3.94058	valid_1's rmse: 31.2703
# [700]	training's rmse: 3.13871	valid_1's rmse: 31.2298
# [800]	training's rmse: 2.52204	valid_1's rmse: 31.2112
# [900]	training's rmse: 2.03692	valid_1's rmse: 31.1929
# [1000]	training's rmse: 1.65574	valid_1's rmse: 31.1777
# [1100]	training's rmse: 1.35819	valid_1's rmse: 31.1611
# [1200]	training's rmse: 1.12194	valid_1's rmse: 31.1562
# [1300]	training's rmse: 0.933524	valid_1's rmse: 31.1516
# [1400]	training's rmse: 0.780864	valid_1's rmse: 31.1451
# [1500]	training's rmse: 0.657348	valid_1's rmse: 31.144
# [1600]	training's rmse: 0.556594	valid_1's rmse: 31.1409
# [1700]	training's rmse: 0.475804	valid_1's rmse: 31.139
# [1800]	training's rmse: 0.409016	valid_1's rmse: 31.1371
# [1900]	training's rmse: 0.353464	valid_1's rmse: 31.1364
# [2000]	training's rmse: 0.307692	valid_1's rmse: 31.1357
# [2100]	training's rmse: 0.270017	valid_1's rmse: 31.1347
# [2200]	training's rmse: 0.238326	valid_1's rmse: 31.1339
# [2300]	training's rmse: 0.211518	valid_1's rmse: 31.133
# [2400]	training's rmse: 0.189324	valid_1's rmse: 31.1327
# [2500]	training's rmse: 0.169191	valid_1's rmse: 31.1322
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.169191	valid_1's rmse: 31.1322
# 40
# fold n°7
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.5346	valid_1's rmse: 25.96
# [200]	training's rmse: 11.8582	valid_1's rmse: 24.6161
# [300]	training's rmse: 8.61683	valid_1's rmse: 24.195
# [400]	training's rmse: 6.52947	valid_1's rmse: 24.0266
# [500]	training's rmse: 5.06094	valid_1's rmse: 23.9363
# [600]	training's rmse: 3.98151	valid_1's rmse: 23.8946
# [700]	training's rmse: 3.1605	valid_1's rmse: 23.8691
# [800]	training's rmse: 2.53058	valid_1's rmse: 23.85
# [900]	training's rmse: 2.04572	valid_1's rmse: 23.8372
# [1000]	training's rmse: 1.66425	valid_1's rmse: 23.8348
# [1100]	training's rmse: 1.3608	valid_1's rmse: 23.828
# [1200]	training's rmse: 1.11703	valid_1's rmse: 23.8285
# Early stopping, best iteration is:
# [1087]	training's rmse: 1.39519	valid_1's rmse: 23.8262
# 406
# fold n°8
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.4962	valid_1's rmse: 26.4021
# [200]	training's rmse: 11.8763	valid_1's rmse: 25.2381
# [300]	training's rmse: 8.6051	valid_1's rmse: 24.8417
# [400]	training's rmse: 6.50357	valid_1's rmse: 24.6908
# [500]	training's rmse: 5.03083	valid_1's rmse: 24.6171
# [600]	training's rmse: 3.93942	valid_1's rmse: 24.5756
# [700]	training's rmse: 3.10733	valid_1's rmse: 24.5594
# [800]	training's rmse: 2.48531	valid_1's rmse: 24.5355
# [900]	training's rmse: 1.99699	valid_1's rmse: 24.5285
# [1000]	training's rmse: 1.62041	valid_1's rmse: 24.5251
# [1100]	training's rmse: 1.32448	valid_1's rmse: 24.5243
# Early stopping, best iteration is:
# [977]	training's rmse: 1.69939	valid_1's rmse: 24.5222
# 12
# fold n°9
#
#
# **** target ****
#
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 17.3989	valid_1's rmse: 28.9245
# [200]	training's rmse: 11.7743	valid_1's rmse: 27.7415
# [300]	training's rmse: 8.5722	valid_1's rmse: 27.4512
# [400]	training's rmse: 6.47547	valid_1's rmse: 27.3571
# [500]	training's rmse: 4.99505	valid_1's rmse: 27.3188
# [600]	training's rmse: 3.91742	valid_1's rmse: 27.281
# [700]	training's rmse: 3.09693	valid_1's rmse: 27.2513
# [800]	training's rmse: 2.4748	valid_1's rmse: 27.2562
# Early stopping, best iteration is:
# [686]	training's rmse: 3.20006	valid_1's rmse: 27.2491
# 336

# %%
_ = plt.figure(figsize=(10, 10))
fi = pd.Series(index=features, data=clf.feature_importance())
_ = fi.sort_values()[-20:].plot(kind='barh')

# %%
rmse(target.values, oofs_df['target'].values)
# Out:
# 27.39625784024737

# %%
predictions_test = current_test_pred
predictions_test[predictions_test < 0] = 0

# %%
SUB_FILE_NAME = 'preds_lgbm_v4.csv'
sub_df = pd.DataFrame()
sub_df[ID_COL] = test[ID_COL]
sub_df[TARGET_COL] = predictions_test
sub_df.to_csv(SUB_FILE_NAME, index=False)
sub_df.head(10)
# Out:
#         Place_ID X Date     target
# 0  0OS9LVX X 2020-01-02  19.239929
# 1  0OS9LVX X 2020-01-03  29.821902
# 2  0OS9LVX X 2020-01-04  20.503900
# 3  0OS9LVX X 2020-01-05  22.019595
# 4  0OS9LVX X 2020-01-06  21.330429
# 5  0OS9LVX X 2020-01-07  17.113558
# 6  0OS9LVX X 2020-01-08  16.050947
# 7  0OS9LVX X 2020-01-09  33.288449
# 8  0OS9LVX X 2020-01-10  29.886790
# 9  0OS9LVX X 2020-01-11  28.703489

# %%
sub_df[TARGET_COL].describe()
# Out:
# count    16136.000000
# mean        58.250069
# std         35.808094
# min          0.000000
# 25%         31.885509
# 50%         48.761607
# 75%         75.559914
# max        295.096232
# Name: target, dtype: float64

# %% [markdown]
# <a href='preds_lgbm_v4.csv'> submission </a>
